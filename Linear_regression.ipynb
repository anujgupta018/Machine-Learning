# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
from sklearn import linear_model

# %%
data=pd.DataFrame({
    "Area":[2600,3000,3200,3600,4000],
    "Price":[550000,565000,610000,680000,725000]
})
data
# Out:
#    Area   Price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
# %matplotlib inline
plt.xlabel('Area(sqrft)')
plt.ylabel('Prices(US$)')
plt.scatter(data.Area,data.Price,color='red',marker='+')

# %%
reg=linear_model.LinearRegression()
reg.fit(data[['Area']],data.Price)
# Out:
# LinearRegression()

# %%
reg.predict([[3300]])
# Out:
# c:\Users\avira\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([628715.75342466])

# %%
plt.xlabel('Area(sqrft)')
plt.ylabel('Prices(US$)')
plt.scatter(data.Area,data.Price,color='red',marker='+')
plt.plot(data.Area,reg.predict(data[['Area']]),color='blue')

# %%
reg.coef_
# Out:
# array([135.78767123])

# %%
reg.intercept_
# Out:
# np.float64(180616.43835616432)

# %%
input_areas=pd.DataFrame({
    "Area":[1000,2000,3000,3700,4100,4876]
})
input_areas.head()
# Out:
#    Area
# 0  1000
# 1  2000
# 2  3000
# 3  3700
# 4  4100

# %%
p=reg.predict(input_areas)

# %%
input_areas['Prices']=p
input_areas
# Out:
#    Area         Prices
# 0  1000  316404.109589
# 1  2000  452191.780822
# 2  3000  587979.452055
# 3  3700  683030.821918
# 4  4100  737345.890411
# 5  4876  842717.123288
